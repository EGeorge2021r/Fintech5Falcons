# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
from pathlib import Path
import numpy as np
import os

# %%
# Using the read_csv function and Path module, create a DataFrame 
# by importing the sfo_neighborhoods_census_data.csv file from the Resources folder
demo_estate_data_df = pd.read_csv(
    Path('tableau_data_Filtered2.csv')
)

# Review the first and last five rows of the DataFrame
demo_estate_data_df
# Out:
# /Applications/anaconda3/envs/dev/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,11,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                   zipCode StateName State  \
# 0                                                    1001       NaN   NaN
# 1                                                    1001       NaN   NaN
# 2                                                    1001       NaN   NaN
# 3                                                    1001       NaN   NaN
# 4                                                    1001       NaN   NaN
# ...                                                   ...       ...   ...
# 781547                                              99950       NaN   NaN
# 781548                                              99950       NaN   NaN
# ...

# %%
demo_estate_data_df.describe()
# Out:
#          Home Value      Inventory  median_listing_price  median_square_feet  \
# count  7.775910e+05  781524.000000          7.775910e+05       777591.000000
# mean   3.375361e+05     111.820958          3.441598e+05         1820.806044
# std    4.201224e+05     815.710807          3.627208e+05          745.000656
# min    1.233700e+04      13.000000          2.000000e+02            0.000000
# 25%    1.519680e+05      25.000000          1.680500e+05         1479.000000
# 50%    2.358060e+05      48.000000          2.592775e+05         1803.500000
# 75%    3.752120e+05      95.000000          3.950500e+05         2189.000000
# max    2.242418e+07   74902.000000          1.980005e+07         9012.000000
#
#             RegionID     SizeRank
# count    3960.000000  3960.000000
# mean   403758.941667    98.125000
# std     56076.781886   127.481227
# min    394304.000000     1.000000
# 25%    394526.250000    30.750000
# 50%    394814.500000    60.500000
# ...

# %%
demo_estate_data_df.State.value_counts()
# Out:
# CA    38105
# TX    34644
# NY    32621
# FL    27951
# PA    23839
# MI    20776
# IL    19339
# OH    16929
# NJ    16239
# NC    16030
# VA    15870
# GA    14810
# WI    12907
# MA    11943
# TN    11894
# MN    11567
# MO    11135
# AL    10190
# IN    10164
# WA    10071
# CO     9711
# MD     9030
# AZ     8685
# CT     7687
# LA     7660
# SC     7514
# KY     7069
# OR     7004
# OK     6982
# ME     6707
# IA     6439
# AR     6187
# KS     5346
# MS     4649
# NH     4594
# WV     4147
# UT     4107
# ID     3682
# VT     3549
# NV     3479
# MT     3167
# NM     3079
# NE     3035
# HI     1992
# RI     1831
# DE     1601
# SD     1489
# WY     1395
# AK     1216
# ND      969
# DC      666
# Name: State, dtype: int64

# %%
tx_df = demo_estate_data_df.loc[demo_estate_data_df.State=="TX"]
tx_df
# Out:
#        zipCode StateName State     City                        Metro  \
# 590682   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590683   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590684   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590685   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590686   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# ...        ...       ...   ...      ...                          ...
# 642314   79938        TX    TX  El Paso                      El Paso
# 642315   79938        TX    TX  El Paso                      El Paso
# 642316   79938        TX    TX  El Paso                      El Paso
# 642317   79938        TX    TX  El Paso                      El Paso
# 642318   79938        TX    TX  El Paso                      El Paso
#
#             CountyName        Date  Home Value  Inventory  \
# 590682   Dallas County  10/31/2017    351009.0       25.0
# ...

# %%
tx_city_df = demo_estate_data_df.loc[demo_estate_data_df.City=="Austin"]
#tx_df = demo_estate_data_df.loc[demo_estate_data_df.City=="Austin"]


tx_city_df
# Out:
#        zipCode StateName State    City              Metro     CountyName  \
# 141892   16720        PA    PA  Austin                NaN  Potter County
# 141893   16720        PA    PA  Austin                NaN  Potter County
# 141894   16720        PA    PA  Austin                NaN  Potter County
# 141895   16720        PA    PA  Austin                NaN  Potter County
# 141896   16720        PA    PA  Austin                NaN  Potter County
# ...        ...       ...   ...     ...                ...            ...
# 636790   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636791   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636792   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636793   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636794   78759        TX    TX  Austin  Austin-Round Rock  Travis County
#
#               Date  Home Value  Inventory  median_listing_price  \
# ...

# %%
austin_df = tx_df.loc[tx_df.City=="Austin"]
austin_df
# Out:
#        zipCode StateName State    City              Metro     CountyName  \
# 633208   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633209   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633210   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633211   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633212   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# ...        ...       ...   ...     ...                ...            ...
# 636790   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636791   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636792   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636793   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636794   78759        TX    TX  Austin  Austin-Round Rock  Travis County
#
#               Date  Home Value  Inventory  median_listing_price  \
# ...

# %%
starbucks_data_df= pd.read_csv(
    Path("../Resources/data/starbucks_data.csv")
)

# %%
display(starbucks_data_df.head())
# Out:
#     name                                               url     street_address  \
# 0   交易廣場   https://www.starbucks.com/store-locator/store/6         中環交易廣場3樓平台
# 1   德福廣場   https://www.starbucks.com/store-locator/store/8   九龍灣德福廣場一期A大堂G1A號
# 2  荷李活廣場   https://www.starbucks.com/store-locator/store/1  九龍鑽石山荷里活廣場2樓298號鋪
# 3  機鐵香港站  https://www.starbucks.com/store-locator/store/13  機鐵香港站HOK 3a & b 號
# 4   太古廣場  https://www.starbucks.com/store-locator/store/17    金鐘道太古廣場L1, 131號
#
#   city state zip_code country phone_number_1  phone_number_2  fax_1  ...  \
# 0   香港    CN      NaN      US       21473739             NaN    NaN  ...
# 1   香港    CN        0      US       27541323             NaN    NaN  ...
# 2   香港    CN      NaN      US       29554570             NaN    NaN  ...
# 3   香港    CN      NaN      US       25375216             NaN    NaN  ...
# 4   香港    CN        0      US       29184762             NaN    NaN  ...
#
# ...

# %%
usa_starbucks_df = starbucks_data_df.loc[starbucks_data_df.country=="US"]

starbucks_df.tail()
# Out:
#                              name  \
# 13613             Village Swindon
# 13614             Xuchang Nanyang
# 13615  Gothenburg Central Station
# 13616      Southside Marketplace.
# 13617      Wurzbach & NW Military
#
#                                                      url  \
# 13613  https://www.starbucks.com/store-locator/store/...
# 13614  https://www.starbucks.com/store-locator/store/...
# 13615  https://www.starbucks.com/store-locator/store/...
# 13616  https://www.starbucks.com/store-locator/store/...
# 13617  https://www.starbucks.com/store-locator/store/...
#
#                                 street_address         city state   zip_code  \
# 13613   Whitehill Way, Shaw Ridge Leisure Park      Swindon    GB    SN5 7DW
# 13614  No.1, Nanyang St., Zhongzheng Dist., 2F  Taipei City    TW      10047
# 13615                        Drottningtorget 1   Gothenburg    SE     411 03
# 13616                 919 E. Fort Ave, Suite A    Baltimore    US  212305117
# ...

# %%
austin_starbucks_df= usa_starbucks_df.loc[usa_starbucks_df.city=="Austin"]


austin_starbucks_df
# Out:
#                                      name  \
# 3780        Target Austin Southpark ST-22
# 4388                     I-35 & Slaughter
# 4546                       Mopac & Parmer
# 4547   I-35 & Barbara Jordan - Mueller W.
# 4807               Circle C on Escarpment
# 5197                     38th & Guadalupe
# 5254       Great Hills Trail & Jollyville
# 6034                  McNeil Dr. & Parmer
# 6206            Target Four Points T-1953
# 6359                 Target Austin T-1061
# 6393            Downtown Austin Courtyard
# 6958                  SR 71 & E Riverside
# 7014       Target Austin Arboretum T-2409
# 7082               Randall's-Austin #2485
# 7482                      10th & Congress
# 7538                          5th & Lamar
# 7722          Walsh Tarlton and Bee Caves
# 7992    6th & Congress - One American Ctr
# 8188                   S. Lamar & Collier
# 8265                        I-35 & Oltorf
# 9308             Target Austin NW ST-1797
# ...

# %%
starbucks_opening_df= pd.read_csv(Path("../Resources/data/starbucks_opening.csv"))
starbucks_opening_df.head()
# Out:
#                                               Opened  \
# 0  11/4/2021\tFranklin Avenue\tFort McMurray\tAlb...
# 1                                 11/1/2021\tGardner
# 2  10/29/2021\tForked River\tForked River\tNewJersey
# 3  10/29/2021\tE Santa Clara & 5th\tSan Jose\tCal...
# 4  10/29/2021\t625 Trunk Road\tSault Ste. Marie\t...
#
#                                           Name City  Market
# 0                                          NaN  NaN     NaN
# 1   W. Broadway\tGardner\tMassachusetts\Boston  NaN     NaN
# 2                                          NaN  NaN     NaN
# 3                                          NaN  NaN     NaN
# 4                                          NaN  NaN     NaN

# %%
austin_starbucks_opening_df= starbucks_opening_df.loc[starbucks_opening_df.City=="austin"]
austin_starbucks_opening_df
# Out:
# Empty DataFrame
# Columns: [Opened, Name, City, Market]
# Index: []

# %%
austin_starbucks_opening_df.City.value_counts()
# Out:
# Series([], Name: City, dtype: int64)
