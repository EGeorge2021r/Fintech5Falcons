# %% [markdown]
# #

# %% [markdown]
# #

# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
from pathlib import Path
import numpy as np
import os

# %%
# Using the read_csv function and Path module, create a DataFrame 
# by importing the sfo_neighborhoods_census_data.csv file from the Resources folder
demo_estate_data_df = pd.read_csv(
    Path('tableau_data_Filtered2.csv')
)

# Review the first and last five rows of the DataFrame
demo_estate_data_df
# Out:
# C:\Users\egeor\anaconda3\envs\pyviz\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (0,11,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                   zipCode StateName State  \
# 0                                                    1001       NaN   NaN
# 1                                                    1001       NaN   NaN
# 2                                                    1001       NaN   NaN
# 3                                                    1001       NaN   NaN
# 4                                                    1001       NaN   NaN
# ...                                                   ...       ...   ...
# 781547                                              99950       NaN   NaN
# 781548                                              99950       NaN   NaN
# ...

# %%
demo_estate_data_df.describe()
# Out:
#          Home Value      Inventory  median_listing_price  median_square_feet  \
# count  7.775910e+05  781524.000000          7.775910e+05       777591.000000
# mean   3.375361e+05     111.820958          3.441598e+05         1820.806044
# std    4.201224e+05     815.710807          3.627208e+05          745.000656
# min    1.233700e+04      13.000000          2.000000e+02            0.000000
# 25%    1.519680e+05      25.000000          1.680500e+05         1479.000000
# 50%    2.358060e+05      48.000000          2.592775e+05         1803.500000
# 75%    3.752120e+05      95.000000          3.950500e+05         2189.000000
# max    2.242418e+07   74902.000000          1.980005e+07         9012.000000
#
#             RegionID     SizeRank
# count    3960.000000  3960.000000
# mean   403758.941667    98.125000
# std     56076.781886   127.481227
# min    394304.000000     1.000000
# 25%    394526.250000    30.750000
# 50%    394814.500000    60.500000
# ...

# %%
#demo_estate_data_df.State.value_counts()

# %%
tx_df = demo_estate_data_df.loc[demo_estate_data_df.State=="TX"]
tx_df
# Out:
#        zipCode StateName State     City                        Metro  \
# 590682   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590683   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590684   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590685   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# 590686   75001        TX    TX  Addison  Dallas-Fort Worth-Arlington
# ...        ...       ...   ...      ...                          ...
# 642314   79938        TX    TX  El Paso                      El Paso
# 642315   79938        TX    TX  El Paso                      El Paso
# 642316   79938        TX    TX  El Paso                      El Paso
# 642317   79938        TX    TX  El Paso                      El Paso
# 642318   79938        TX    TX  El Paso                      El Paso
#
#             CountyName        Date  Home Value  Inventory  \
# 590682   Dallas County  10/31/2017    351009.0       25.0
# ...

# %%
austin_df = tx_df.loc[tx_df.City=="Austin"]
austin_df
# Out:
#        zipCode StateName State    City              Metro     CountyName  \
# 633208   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633209   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633210   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633211   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# 633212   78617        TX    TX  Austin  Austin-Round Rock  Travis County
# ...        ...       ...   ...     ...                ...            ...
# 636790   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636791   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636792   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636793   78759        TX    TX  Austin  Austin-Round Rock  Travis County
# 636794   78759        TX    TX  Austin  Austin-Round Rock  Travis County
#
#               Date  Home Value  Inventory  median_listing_price  \
# ...

# %%
starbucks_data_df= pd.read_csv(
    Path("../Resources/data/starbucks_data.csv")
)
starbucks_data_df
# Out:
#                              name                           street_address  \
# 0                            交易廣場                               中環交易廣場3樓平台
# 1                            德福廣場                         九龍灣德福廣場一期A大堂G1A號
# 2                           荷李活廣場                        九龍鑽石山荷里活廣場2樓298號鋪
# 3                           機鐵香港站                        機鐵香港站HOK 3a & b 號
# 4                            太古廣場                          金鐘道太古廣場L1, 131號
# ...                           ...                                      ...
# 13613             Village Swindon   Whitehill Way, Shaw Ridge Leisure Park
# 13614             Xuchang Nanyang  No.1, Nanyang St., Zhongzheng Dist., 2F
# 13615  Gothenburg Central Station                        Drottningtorget 1
# 13616      Southside Marketplace.                 919 E. Fort Ave, Suite A
# 13617      Wurzbach & NW Military                12003 NW Military Highway
#
# ...

# %%
display(starbucks_data_df.head())
# Out:
#     name     street_address city state zip_code country phone_number_1  \
# 0   交易廣場         中環交易廣場3樓平台   香港    CN      NaN      US       21473739
# 1   德福廣場   九龍灣德福廣場一期A大堂G1A號   香港    CN        0      US       27541323
# 2  荷李活廣場  九龍鑽石山荷里活廣場2樓298號鋪   香港    CN      NaN      US       29554570
# 3  機鐵香港站  機鐵香港站HOK 3a & b 號   香港    CN      NaN      US       25375216
# 4   太古廣場    金鐘道太古廣場L1, 131號   香港    CN        0      US       29184762
#
#    phone_number_2  fax_1  fax_2  ...  email_2  website  \
# 0             NaN    NaN    NaN  ...      NaN      NaN
# 1             NaN    NaN    NaN  ...      NaN      NaN
# 2             NaN    NaN    NaN  ...      NaN      NaN
# 3             NaN    NaN    NaN  ...      NaN      NaN
# 4             NaN    NaN    NaN  ...      NaN      NaN
#
#                                           open_hours   latitude   longitude  \
# 0  Wednesday : 6:30 AM to 8:30 PM, Thursday : 6:3...  22.283940  114.158190
# ...

# %%
austin_starbucks_df= starbucks_data_df.loc[starbucks_data_df.city=="Austin"]

display(austin_starbucks_df.tail())
# Out:
#                                      name            street_address    city  \
# 11933            Ben White & Payload Pass  500A East Ben White Blvd  Austin
# 12164             Randalls - Austin #2483            715 Exposition  Austin
# 12500                 Rockwood & Anderson   2900 West Anderson Lane  Austin
# 12511                      SR 71 & US 290      7015 West US Hwy 290  Austin
# 13268  University of Texas Austin-Student             2101 Speedway  Austin
#
#       state   zip_code country  phone_number_1  phone_number_2  fax_1  fax_2  \
# 11933    US  787047488      US  (512) 912-9188             NaN    NaN    NaN
# 12164    US  787033615      US      5124775713             NaN    NaN    NaN
# 12500    US  787571102      US    512-467-1548             NaN    NaN    NaN
# 12511    US      78736      US    512-288-0662             NaN    NaN    NaN
# 13268    US  787121013      US    512-471-6163             NaN    NaN    NaN
#
#        ...  email_2  website  \
# ...

# %%
# Remove muliple columns not relevant to analysis
#clean_austin_starbucks_df= 
clean_austin_starbucks_df = austin_starbucks_df.drop(['phone_number_1', 'phone_number_2', 'email_1', 'email_2', 'website', 'open_hours', 'facebook', 'twitter', 'instagram', 'pinterest', 'youtube', 'fax_1', 'fax_2'], axis = 1)

clean_austin_starbucks_df
# Out:
#                                      name  \
# 3780        Target Austin Southpark ST-22
# 4388                     I-35 & Slaughter
# 4546                       Mopac & Parmer
# 4547   I-35 & Barbara Jordan - Mueller W.
# 4807               Circle C on Escarpment
# 5197                     38th & Guadalupe
# 5254       Great Hills Trail & Jollyville
# 6034                  McNeil Dr. & Parmer
# 6206            Target Four Points T-1953
# 6359                 Target Austin T-1061
# 6393            Downtown Austin Courtyard
# 6958                  SR 71 & E Riverside
# 7014       Target Austin Arboretum T-2409
# 7082               Randall's-Austin #2485
# 7482                      10th & Congress
# 7538                          5th & Lamar
# 7722          Walsh Tarlton and Bee Caves
# 7992    6th & Congress - One American Ctr
# 8188                   S. Lamar & Collier
# 8265                        I-35 & Oltorf
# 9308             Target Austin NW ST-1797
# ...

# %%
# Sorting by column "zip_code"
clean_austin_starbucks_df.sort_values(by=['zip_code'], ascending=True)
# Out:
#                                      name  \
# 9952                   15th & San Antonio
# 7992    6th & Congress - One American Ctr
# 6393            Downtown Austin Courtyard
# 7482                      10th & Congress
# 11095   Exposition & Westover - Casis Vlg
# 12164             Randalls - Austin #2483
# 7538                          5th & Lamar
# 8188                   S. Lamar & Collier
# 8265                        I-35 & Oltorf
# 11933            Ben White & Payload Pass
# 7082               Randall's-Austin #2485
# 11313      Brodie Oaks Center on S. Lamar
# 5197                     38th & Guadalupe
# 11189       W.24th & Nueces (White House)
# 13268  University of Texas Austin-Student
# 9308             Target Austin NW ST-1797
# 4547   I-35 & Barbara Jordan - Mueller W.
# 10364                  Hwy 620 & Hwy 2222
# 4546                       Mopac & Parmer
# 10371                     Metric & Parmer
# 6034                  McNeil Dr. & Parmer
# ...

# %%
# Filter dataframe from Zipcode 78701 to 78705 for analysis
neighborhood_austin_starbucks_df = clean_austin_starbucks_df.iloc[0:14]                                                             
neighborhood_austin_starbucks_df
# Out:
#                                     name  \
# 3780       Target Austin Southpark ST-22
# 4388                    I-35 & Slaughter
# 4546                      Mopac & Parmer
# 4547  I-35 & Barbara Jordan - Mueller W.
# 4807              Circle C on Escarpment
# 5197                    38th & Guadalupe
# 5254      Great Hills Trail & Jollyville
# 6034                 McNeil Dr. & Parmer
# 6206           Target Four Points T-1953
# 6359                Target Austin T-1061
# 6393           Downtown Austin Courtyard
# 6958                 SR 71 & E Riverside
# 7014      Target Austin Arboretum T-2409
# 7082              Randall's-Austin #2485
#
#                             street_address    city state   zip_code country  \
# 3780         9500 S I-35, Feeder Rd Bldg G  Austin    US  787481752      US
# 4388  9300 S I-35 Service Rd S Bound, G100  Austin    US  787481733      US
# 4546                      2505 Parmer Lane  Austin    US  787274212      US
# ...

# %%
#Display the Dataframe first 5 rows or head 
neighborhood_austin_starbucks_df.head()
# Out:
#                                     name  \
# 3780       Target Austin Southpark ST-22
# 4388                    I-35 & Slaughter
# 4546                      Mopac & Parmer
# 4547  I-35 & Barbara Jordan - Mueller W.
# 4807              Circle C on Escarpment
#
#                             street_address    city state   zip_code country  \
# 3780         9500 S I-35, Feeder Rd Bldg G  Austin    US  787481752      US
# 4388  9300 S I-35 Service Rd S Bound, G100  Austin    US  787481733      US
# 4546                      2505 Parmer Lane  Austin    US  787274212      US
# 4547       1201 Barbara Jordan Blvd., 1200  Austin    US  787233083      US
# 4807      9600 Escarpment Blvd Bldg F, 700  Austin    US  787491982      US
#
#        latitude  longitude
# 3780  30.163772 -97.793198
# 4388  30.165438 -97.788176
# 4546  30.418882 -97.702713
# 4547  30.305797 -97.707999
# 4807  30.202645 -97.878722

# %%
#Display the Dataframe last 5 rows or tail
neighborhood_austin_starbucks_df.tail()
# Out:
#                                 name              street_address    city  \
# 6359            Target Austin T-1061          5300 S Mo Pac Expy  Austin
# 6393       Downtown Austin Courtyard                300 E 4th St  Austin
# 6958             SR 71 & E Riverside  7709 E Ben White Blvd, 100  Austin
# 7014  Target Austin Arboretum T-2409         10107 Research Blvd  Austin
# 7082          Randall's-Austin #2485       2025 W Ben White Blvd  Austin
#
#      state   zip_code country   latitude  longitude
# 6359    US  787491112      US  30.233992 -97.828317
# 6393    US  787013612      US  30.265468 -97.740448
# 6958    US  787441773      US  30.217703 -97.689971
# 7014    US  787595803      US  30.392741 -97.744430
# 7082    US  787047518      US  30.229427 -97.790097

# %%
starbucks_opening_df= pd.read_csv(Path("../Resources/data/starbucks_openingv2.csv"))
starbucks_opening_df
# Out:
#           Opened                       Name              City  \
# 0      11/4/2021            Franklin Avenue     Fort McMurray
# 1      11/1/2021       Gardner, W. Broadway           Gardner
# 2     10/29/2021               Forked River      Forked River
# 3     10/29/2021        E Santa Clara & 5th          San Jose
# 4     10/29/2021             625 Trunk Road  Sault Ste. Marie
# ...          ...                        ...               ...
# 6712   8/30/1991             Vancouver Mall         Vancouver
# 6713    3/2/1991  Robson - Robson & Thurlow         Vancouver
# 6714   9/29/1989               Trade Center     Coral Springs
# 6715   8/28/1989         Pioneer Courthouse          Portland
# 6716    3/1/1987                     Seabus         Vancouver
#
#                                  Market  zip_code
# 0          Alberta\AlbertaRemoteMarkets       NaN
# 1                  Massachusetts\Boston       NaN
# 2                             NewJersey       NaN
# ...

# %%
#starbucks_opening_df.City.value_counts()

# %%
# Filter starbucks opening locations in Austin City only
austin_starbucks_opening_df= starbucks_opening_df.loc[starbucks_opening_df.City=="Austin"].dropna()
austin_starbucks_opening_df
# Out:
#           Opened                        Name    City        Market  zip_code
# 35     10/3/2021  Pickup - 22nd & Rio Grande  Austin  Texas\Austin   78705.0
# 748    6/15/2020        Burnet & Braker Lane  Austin  Texas\Austin   78758.0
# 801     5/6/2020         FM 620 & Vista Park  Austin  Texas\Austin   78681.0
# 1474    1/7/2019      Hwy 71 & Cardinal Loop  Austin  Texas\Austin   78617.0
# 1626   10/1/2018   Barton Springs & S. Lamar  Austin  Texas\Austin   78704.0
# 1805   6/18/2018    Far West Blvd at Hart Ln  Austin  Texas\Austin   78731.0
# 2216   9/29/2017             Parmer & Dessau  Austin  Texas\Austin   78753.0
# 2225   9/27/2017        The Domain Northside  Austin  Texas\Austin   78759.0
# 2557    3/8/2017         Anderson Mill & 183  Austin  Texas\Austin   78750.0
# 2816   8/29/2016                1st & Oltorf  Austin  Texas\Austin   78704.0
# 3444    4/7/2015           Riverside & Arena  Austin  Texas\Austin   78701.0
# ...

# %%
# Filter dataframe from 2014  to 2021  for analysis
data_starbucks_opening_df = austin_starbucks_opening_df.iloc[0:13]                                                               
data_starbucks_opening_df
# Out:
#           Opened                        Name    City        Market  zip_code
# 35     10/3/2021  Pickup - 22nd & Rio Grande  Austin  Texas\Austin   78705.0
# 748    6/15/2020        Burnet & Braker Lane  Austin  Texas\Austin   78758.0
# 801     5/6/2020         FM 620 & Vista Park  Austin  Texas\Austin   78681.0
# 1474    1/7/2019      Hwy 71 & Cardinal Loop  Austin  Texas\Austin   78617.0
# 1626   10/1/2018   Barton Springs & S. Lamar  Austin  Texas\Austin   78704.0
# 1805   6/18/2018    Far West Blvd at Hart Ln  Austin  Texas\Austin   78731.0
# 2216   9/29/2017             Parmer & Dessau  Austin  Texas\Austin   78753.0
# 2225   9/27/2017        The Domain Northside  Austin  Texas\Austin   78759.0
# 2557    3/8/2017         Anderson Mill & 183  Austin  Texas\Austin   78750.0
# 2816   8/29/2016                1st & Oltorf  Austin  Texas\Austin   78704.0
# 3444    4/7/2015           Riverside & Arena  Austin  Texas\Austin   78701.0
# ...
